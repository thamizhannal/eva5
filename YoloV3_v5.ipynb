# %% [markdown]
# <a href="https://colab.research.google.com/github/thamizhannal/eva5/blob/master/YoloV3_v5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import time
import glob
import torch
import os

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.6.0+cu101 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15079MB, multi_processor_count=40)

# %%
# !ls
# Out:
# gdrive	sample_data

# %%
# %cd /content/gdrive/'My Drive'/SchoolOfAI_EVA/YoloV3_S13/YoloV3
# Out:
# /content/gdrive/.shortcut-targets-by-id/1fy-bcuqz4n6fv8WZHdkFelEpy9YGc-Hx/YoloV3_S13/YoloV3

# %%
# !ls
# Out:
#  cfg		 models.py      results.png  'ubdivisions=1'
#  data		 output         runs	      utils
#  detect.py	 __pycache__    test.py       vim.exe.stackdump
#  image_wip.csv	 README.md      ting	      weights
#  label_wip.csv	 results.json   train.py      YoLoV3_Output

# %%
# !ls data/customdata/
# Out:
# custom.data   images  test.shapes  train.shapes
# custom.names  labels  test.txt	   train.txt

# %%
# !ls 'weights'
# Out:
# last.pt  yolov3-spp-ultralytics.pt

# %%
# !ls cfg/
# Out:
# yolov3-custom.cfg  yolov3-spp.cfg

# %%
# !python train.py --data data/customdata/custom.data --batch 10 --cache --cfg cfg/yolov3-custom.cfg --epochs 3 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=10, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=3, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# 2020-10-26 08:49:25.070655: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# Caching labels (3065 found, 139 missing, 0 empty, 0 duplicate, for 3204 images): 100% 3204/3204 [07:54<00:00,  6.76it/s]
# Caching images (1.8GB): 100% 3204/3204 [09:55<00:00,  5.38it/s]
# ...

# %%
# !ls YoLoV3_Output
# Out:
# 'Copy of image-121.png'      'Copy of image-216 (2).png'   image-100.png
# 'Copy of image-122.png'      'Copy of image-216.png'	   image-101.png
# 'Copy of image-123.png'      'Copy of image-217 (1).png'   image-102.png
# 'Copy of image-124.png'      'Copy of image-217 (2).png'   image-103.png
# 'Copy of image-125.png'      'Copy of image-217.png'	   image-104.png
# 'Copy of image-126.png'      'Copy of image-218 (1).png'   image-105.png
# 'Copy of image-127.png'      'Copy of image-218 (2).png'   image-106.png
# 'Copy of image-128.png'      'Copy of image-218.png'	   image-107.png
# 'Copy of image-129.png'      'Copy of image-219 (1).png'   image-108.png
# 'Copy of image-130.png'      'Copy of image-219 (2).png'   image-109.png
# 'Copy of image-131.png'      'Copy of image-219.png'	   image-110.png
# 'Copy of image-132.png'      'Copy of image-220 (1).png'   image-111.png
# 'Copy of image-133.png'      'Copy of image-220 (2).png'   image-112.png
# ...

# %%
# !python detect.py --source /content/gdrive/'My Drive'/SchoolOfAI_EVA/input_images_video --conf-thres 0.3 --output YoLoV3_Output
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.3, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='YoLoV3_Output', save_txt=False, source='/content/gdrive/My Drive/SchoolOfAI_EVA/input_images_video', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# image 1/382 /content/gdrive/My Drive/SchoolOfAI_EVA/input_images_video/Copy of image-121.png: 320x512 Done. (0.033s)
# image 2/382 /content/gdrive/My Drive/SchoolOfAI_EVA/input_images_video/Copy of image-122.png: 320x512 Done. (0.033s)
# image 3/382 /content/gdrive/My Drive/SchoolOfAI_EVA/input_images_video/Copy of image-123.png: 320x512 Done. (0.033s)
# image 4/382 /content/gdrive/My Drive/SchoolOfAI_EVA/input_images_video/Copy of image-124.png: 320x512 Done. (0.033s)
# ...

# %%
Image(filename='YoLoV3_Output/image-223.png', width=600)

# %%
Image(filename='YoLoV3_Output/image-198.png', width=600)

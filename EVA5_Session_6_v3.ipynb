# %% [markdown]
# <a href="https://colab.research.google.com/github/thamizhannal/eva5/blob/master/EVA5_Session_6_v3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Target:
# Reach 99.4% accuracy consistently in last 3-4 epochs by a applying more regularization in the form of dropout and increase LR rate to understand if convergence occurs faster and use LR schedular to change LR wherever Loss gets to plateau
#
# ###Results:
# 1. Parameters: 7,917
# 2. Best Train Accuracy: 99.08%
# 3. Best Test Accuracy: 99.43%
# 4. greater than 99.4% in last 4 epochs(12-15)
#
# ###Analysis:
# 1. Dropout added the necessary regularization required to make model robust
# 2. Though increased LR was helping in fast convergence but after 5-6 epochs it would tapper off implying a need for smaller LR so used a step LR schedule at after 4 epochs and decreased it to 0.8 times the previous LR
#
# ###All the changes added to the base CNN architechture to acheive the target accuracy
# 1. Input image normalization
# 2. Image augmentation - rotation for Train data
# 3. Batch Normalization
# 4. Dropouts
# 5. LR scheduler
# 6. GAP

# %%
from __future__ import print_function
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms

# %%
# Reused below code from https://github.com/apple/ml-cifar-10-faster/blob/master/utils.py
# GhostBatchNormalization
class BatchNorm(nn.BatchNorm2d):
    def __init__(self, num_features, eps=1e-05, momentum=0.1, weight=True, bias=True):
        super().__init__(num_features, eps=eps, momentum=momentum)
        self.weight.data.fill_(1.0)
        self.bias.data.fill_(0.0)
        self.weight.requires_grad = weight
        self.bias.requires_grad = bias

class GhostBatchNorm(BatchNorm):
    def __init__(self, num_features, num_splits, **kw):
        super().__init__(num_features, **kw)
        self.num_splits = num_splits
        self.register_buffer('running_mean', torch.zeros(num_features * self.num_splits))
        self.register_buffer('running_var', torch.ones(num_features * self.num_splits))

    def train(self, mode=True):
        if (self.training is True) and (mode is False):  # lazily collate stats when we are going to use them
            self.running_mean = torch.mean(self.running_mean.view(self.num_splits, self.num_features), dim=0).repeat(
                self.num_splits)
            self.running_var = torch.mean(self.running_var.view(self.num_splits, self.num_features), dim=0).repeat(
                self.num_splits)
        return super().train(mode)

    def forward(self, input):
        N, C, H, W = input.shape
        if self.training or not self.track_running_stats:
            return F.batch_norm(
                input.view(-1, C * self.num_splits, H, W), self.running_mean, self.running_var,
                self.weight.repeat(self.num_splits), self.bias.repeat(self.num_splits),
                True, self.momentum, self.eps).view(N, C, H, W)
        else:
            return F.batch_norm(
                input, self.running_mean[:self.num_features], self.running_var[:self.num_features],
                self.weight, self.bias, False, self.momentum, self.eps)

# %%
num_splits = 2
#Receptive field is calcualted based on actual formula
class Net(nn.Module):
    def __init__(self, enable_bn=True ):
        super(Net, self).__init__()
        self.enable_bn = enable_bn

        #block1
        self.conv1 = nn.Conv2d(1, 8, 3,padding = True) #o/p size:28; rf: 3
        self.Batchnorm1 = nn.BatchNorm2d(8)
        if not enable_bn:
            self.Batchnorm1 = GhostBatchNorm(num_features=8, num_splits=num_splits)
        
        self.conv2 = nn.Conv2d(8, 16, 3) #o/p size: 26; rf: 5
        self.Batchnorm2 = nn.BatchNorm2d(16)
        if not enable_bn:
            self.Batchnorm2 = GhostBatchNorm(num_features=16, num_splits=num_splits)


        #transition block
        self.pool1 = nn.MaxPool2d(2, 2) #o/p size: 13; rf: 6
        self.pool1trns = nn.Conv2d(16, 10, 1)#o/p size: 13; rf: 6 
        self.Batchnormtrns1 = nn.BatchNorm2d(10)
        if not enable_bn:
            self.Batchnormtrns1 = GhostBatchNorm(num_features=10, num_splits=num_splits)
        
        #block2
        self.conv3 = nn.Conv2d(10,14,3) #o/p size: 11; rf: 10 # 14
        self.Batchnorm3 = nn.BatchNorm2d(14)
        if not enable_bn:
            self.Batchnorm3 = GhostBatchNorm(num_features=14, num_splits=num_splits)

        self.dp3 = nn.Dropout(p = 0.10) 
        self.conv4 = nn.Conv2d(14, 16, 3) #o/p size: 9; rf: 14
        self.Batchnorm4 = nn.BatchNorm2d(16)
        if not enable_bn:
            self.Batchnorm4 = GhostBatchNorm(num_features=16, num_splits=num_splits)

        self.dp4 = nn.Dropout(p = 0.10)
        self.conv5 = nn.Conv2d(16, 20, 3) #o/p size: 7; rf: 18
        self.Batchnorm5 = nn.BatchNorm2d(20)
        if not enable_bn:
            self.Batchnorm5 = GhostBatchNorm(num_features=20, num_splits=num_splits)

        self.dp5 = nn.Dropout(p = 0.10)

        #gap and 1X1 
        self.conv6_avgp = nn.AvgPool2d(kernel_size=7) #o/p size: 1; rf: 30
        self.pool2trns = nn.Conv2d(20,10,1) #6


    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = self.Batchnorm1(x)

        x = self.conv2(x)
        x = F.relu(x)
        x = self.Batchnorm2(x)


        x = self.pool1(x)
        x = self.pool1trns(x)
        x = F.relu(x)
        x = self.Batchnormtrns1(x)

        x = self.conv3(x)
        x = F.relu(x)
        x = self.Batchnorm3(x)
        x = self.dp3(x)
 
        x = self.conv4(x)
        x = F.relu(x)
        x = self.Batchnorm4(x)
        x = self.dp4(x)

        x = self.conv5(x)
        x = F.relu(x)
        x = self.Batchnorm5(x)
        x = self.dp5(x)

        x = self.conv6_avgp(x)

        x = self.pool2trns(x)


        x = x.view(-1, 10)
        return F.log_softmax(x,dim=-1)

# %%
#!pip install torchsummary
from torchsummary import summary
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
model = Net(True).to(device)

summary(model, input_size=(1, 28, 28))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 8, 28, 28]              80
#        BatchNorm2d-2            [-1, 8, 28, 28]              16
#             Conv2d-3           [-1, 16, 26, 26]           1,168
#        BatchNorm2d-4           [-1, 16, 26, 26]              32
#          MaxPool2d-5           [-1, 16, 13, 13]               0
#             Conv2d-6           [-1, 10, 13, 13]             170
#        BatchNorm2d-7           [-1, 10, 13, 13]              20
#             Conv2d-8           [-1, 14, 11, 11]           1,274
#        BatchNorm2d-9           [-1, 14, 11, 11]              28
#           Dropout-10           [-1, 14, 11, 11]               0
#            Conv2d-11             [-1, 16, 9, 9]           2,032
#       BatchNorm2d-12             [-1, 16, 9, 9]              32
#           Dropout-13             [-1, 16, 9, 9]               0
#            Conv2d-14             [-1, 20, 7, 7]           2,900
#       BatchNorm2d-15             [-1, 20, 7, 7]              40
#           Dropout-16             [-1, 20, 7, 7]               0
#         AvgPool2d-17             [-1, 20, 1, 1]               0
#            Conv2d-18             [-1, 10, 1, 1]             210
# ================================================================
# Total params: 8,002
# Trainable params: 8,002
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.40
# Params size (MB): 0.03
# Estimated Total Size (MB): 0.43
# ----------------------------------------------------------------

# %%
torch.manual_seed(1)
batch_size = 64

kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}
train_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=True, download=True,
                    transform=transforms.Compose([
                        transforms.RandomRotation((-8.0, 8.0), fill=(1,)),
                        transforms.ToTensor(),
                        transforms.Normalize((0.1307,), (0.3081,))
                    ])),
    batch_size=batch_size, shuffle=True, **kwargs)


test_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=False, transform=transforms.Compose([
                        transforms.ToTensor(),
                        transforms.Normalize((0.1307,), (0.3081,))
                    ])),
    batch_size=batch_size, shuffle=True, **kwargs)

# %%
train_losses, train_accuracy = [], []
val_losses = []
val_accuracy = []

from tqdm import tqdm
def train(model, device, train_loader, optimizer, epoch, 
          enable_l1=False, enable_l2=False, enable_gbn=False):
    model.train()
    #pbar = tqdm(train_loader)
    train_loss = 0 
    train_correct = 0
    train_acc = 0

    # For best lambda value, apply grid search
    lambda_l1 = 0.001
    #scheduler.step()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = F.nll_loss(output, target)

        # loss function
        # L1 loss
        if (enable_l1 and not (enable_l2 and enable_gbn)):
            l1_loss = 0
            for param in model.parameters():
                l1_loss = l1_loss + param.abs().sum()
            loss = loss + lambda_l1 * l1_loss
        # L2 loss    
        #elif enable_l2 and not (enable_l1 and enable_gbn):
            #print ("LOSS:l2")
        # L1L2 loss
        #elif enable_l1 and enable_l2 and not enable_gbn:
            #print("l1l2")
        # GBN only
        #elif enable_gbn and not (enable_l1 and enable_l2) :  
            #print("gbn only")
        # L1L2&GBN loss
        #elif enable_gbn and enable_l1 and enable_l2 :  
            #print("l1l2gbn")
        #

        loss.backward()
        optimizer.step()
        #pbar.set_description(desc= f'loss={loss.item()} batch_id={batch_idx}')
        train_loss += F.nll_loss(output, target, reduction='sum').item()  # sum up batch loss
        pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
        train_correct += pred.eq(target.view_as(pred)).sum().item()

    #
    train_loss /= len(train_loader.dataset)
    train_acc = 100. * train_correct / len(train_loader.dataset)
    train_losses.append(train_loss)
    train_accuracy.append(train_acc)

    #train_loss /= len(test_loader.dataset)
    
    print('Epoch: {:.0f},LR: {}.\nTrain set: train Average loss: {:.4f}, train_Accuracy: {}/{} ({:.4f}%)\n'.format(
        epoch,optimizer.param_groups[0]['lr'],train_loss, train_correct, len(train_loader.dataset),
        100. * train_correct / len(train_loader.dataset)))
    return train_losses,train_accuracy
        

def test(model, device, test_loader):
    model.eval()
    test_loss = 0
    correct = 0

    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item()  # sum up batch loss

            pred_test = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
            correct += pred_test.eq(target.view_as(pred_test)).sum().item()

    test_loss /= len(test_loader.dataset)
    val_acc = 100. * correct / len(test_loader.dataset)
    
    #val_losses.append(test_loss)
    #val_accuracy.append(val_acc)

    
    print('Test set: test Average loss: {:.4f}, test Accuracy: {}/{} ({:.4f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    return test_loss, val_acc

# %%
from torch.optim.lr_scheduler import StepLR

# Loop To Run Network 
# 1. with L1 + BN
# 2. with L2 + BN
# 3. with L1 and L2 with BN
# 4. with GBN
# 5. with L1 and L2 with GBN

losses = ['l1', 'l2', 'l1&l2', 'gbn', 'l1l2gbn']

val_losses = []
val_accs = []

for idx in range(len(losses)):
    i = idx+1
    enable_l1 = False
    enable_l2 = False
    enable_gbn = False

    print("{} {} loss".format((i),losses[idx]))
    ######### Model Initialization #############################################
    # Enable BN for option 1, 2 & 3
    if i == 1 or i==2 or i==3:
        model = Net(enable_bn=True).to(device)
        print("BN enabled for option: {}".format(i))
    # Enable GBN for option 4 & 5( disable BN)
    elif i==4 or i==5:
        model = Net(enable_bn=False).to(device)
        print("GBN Enabled & BN disabled for option: {}".format(i))
    print ("Model Summary:")
    summary(model, input_size=(1, 28, 28))

    ########## Optimizer Initialization #######################################
    optimizer = optim.SGD(model.parameters(), lr=0.03, momentum=0.9)
    if i==2 or i==3 or i==5:
        # decay of 0.0001 gave best val accuracy 99.38
        decay = 0.0001
        optimizer = optim.SGD(model.parameters(), lr=0.03, momentum=0.9, weight_decay=decay)  
        print("Weight decay {} set for option: {}".format(decay, i))
    
    scheduler = StepLR(optimizer, step_size=4, gamma=0.8)
    ######### Loss Function Selection #########################################
    if i==1:
         enable_l1 = True
         print("LOSS: l1 loss enabled")
    elif i==2:
         enable_l2 = True
         print("LOSS: l2 loss enabled")
    elif i==3:
         enable_l1 = True
         enable_l2=True
         print("LOSS: l1l2 loss enabled")
    elif i==4:         
         enable_gbn = True
         print("LOSS: gbn loss enabled")
    elif i==5:
         enable_l1 = True
         enable_l2=True
         enable_gbn = True
         print("LOSS: l1l2gbn loss enabled")
    val_loss = []
    val_acc = []
    for epoch in range(1, 26):
        train(model, device, train_loader, optimizer, epoch, 
              enable_l1=enable_l1, enable_l2=enable_l2, enable_gbn=enable_gbn)
        scheduler.step()
        loss, acc = test(model, device, test_loader)
        val_loss.append(loss)
        val_acc.append(acc)

    val_losses.append(val_loss)
    val_accs.append(val_acc)
# Out:
# 1 l1 loss
# BN enabled for option: 1
# Model Summary:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 8, 28, 28]              80
#        BatchNorm2d-2            [-1, 8, 28, 28]              16
#             Conv2d-3           [-1, 16, 26, 26]           1,168
#        BatchNorm2d-4           [-1, 16, 26, 26]              32
#          MaxPool2d-5           [-1, 16, 13, 13]               0
#             Conv2d-6           [-1, 10, 13, 13]             170
#        BatchNorm2d-7           [-1, 10, 13, 13]              20
#             Conv2d-8           [-1, 14, 11, 11]           1,274
#        BatchNorm2d-9           [-1, 14, 11, 11]              28
#           Dropout-10           [-1, 14, 11, 11]               0
#            Conv2d-11             [-1, 16, 9, 9]           2,032
#       BatchNorm2d-12             [-1, 16, 9, 9]              32
#           Dropout-13             [-1, 16, 9, 9]               0
#            Conv2d-14             [-1, 20, 7, 7]           2,900
#       BatchNorm2d-15             [-1, 20, 7, 7]              40
#           Dropout-16             [-1, 20, 7, 7]               0
#         AvgPool2d-17             [-1, 20, 1, 1]               0
#            Conv2d-18             [-1, 10, 1, 1]             210
# ================================================================
# Total params: 8,002
# Trainable params: 8,002
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.40
# Params size (MB): 0.03
# Estimated Total Size (MB): 0.43
# ----------------------------------------------------------------
# LOSS: l1 loss enabled
# Epoch: 1,LR: 0.03.
# Train set: train Average loss: 0.2847, train_Accuracy: 55029/60000 (91.7150%)
#
# Test set: test Average loss: 0.2008, test Accuracy: 9312/10000 (93.1200%)
#
# Epoch: 2,LR: 0.03.
# Train set: train Average loss: 0.1353, train_Accuracy: 57624/60000 (96.0400%)
#
# Test set: test Average loss: 0.1014, test Accuracy: 9737/10000 (97.3700%)
#
# Epoch: 3,LR: 0.03.
# Train set: train Average loss: 0.1302, train_Accuracy: 57672/60000 (96.1200%)
#
# Test set: test Average loss: 0.1848, test Accuracy: 9415/10000 (94.1500%)
#
# Epoch: 4,LR: 0.03.
# Train set: train Average loss: 0.1313, train_Accuracy: 57637/60000 (96.0617%)
#
# Test set: test Average loss: 0.0990, test Accuracy: 9716/10000 (97.1600%)
#
# Epoch: 5,LR: 0.024.
# Train set: train Average loss: 0.1209, train_Accuracy: 57846/60000 (96.4100%)
#
# Test set: test Average loss: 0.1287, test Accuracy: 9589/10000 (95.8900%)
#
# Epoch: 6,LR: 0.024.
# Train set: train Average loss: 0.1225, train_Accuracy: 57858/60000 (96.4300%)
#
# Test set: test Average loss: 0.2067, test Accuracy: 9341/10000 (93.4100%)
#
# Epoch: 7,LR: 0.024.
# Train set: train Average loss: 0.1219, train_Accuracy: 57802/60000 (96.3367%)
#
# Test set: test Average loss: 0.3142, test Accuracy: 9014/10000 (90.1400%)
#
# Epoch: 8,LR: 0.024.
# Train set: train Average loss: 0.1246, train_Accuracy: 57743/60000 (96.2383%)
#
# Test set: test Average loss: 0.0691, test Accuracy: 9798/10000 (97.9800%)
#
# Epoch: 9,LR: 0.019200000000000002.
# Train set: train Average loss: 0.1157, train_Accuracy: 57912/60000 (96.5200%)
#
# Test set: test Average loss: 0.0956, test Accuracy: 9721/10000 (97.2100%)
#
# Epoch: 10,LR: 0.019200000000000002.
# Train set: train Average loss: 0.1154, train_Accuracy: 57921/60000 (96.5350%)
#
# Test set: test Average loss: 0.0883, test Accuracy: 9738/10000 (97.3800%)
#
# Epoch: 11,LR: 0.019200000000000002.
# Train set: train Average loss: 0.1155, train_Accuracy: 57890/60000 (96.4833%)
#
# Test set: test Average loss: 0.0911, test Accuracy: 9723/10000 (97.2300%)
#
# Epoch: 12,LR: 0.019200000000000002.
# Train set: train Average loss: 0.1168, train_Accuracy: 57901/60000 (96.5017%)
#
# Test set: test Average loss: 0.1435, test Accuracy: 9581/10000 (95.8100%)
#
# Epoch: 13,LR: 0.015360000000000002.
# Train set: train Average loss: 0.1076, train_Accuracy: 58082/60000 (96.8033%)
#
# Test set: test Average loss: 0.1503, test Accuracy: 9505/10000 (95.0500%)
#
# Epoch: 14,LR: 0.015360000000000002.
# Train set: train Average loss: 0.1107, train_Accuracy: 58015/60000 (96.6917%)
#
# Test set: test Average loss: 0.0654, test Accuracy: 9796/10000 (97.9600%)
#
# Epoch: 15,LR: 0.015360000000000002.
# Train set: train Average loss: 0.1124, train_Accuracy: 57942/60000 (96.5700%)
#
# Test set: test Average loss: 0.0950, test Accuracy: 9712/10000 (97.1200%)
#
# Epoch: 16,LR: 0.015360000000000002.
# Train set: train Average loss: 0.1148, train_Accuracy: 57912/60000 (96.5200%)
#
# Test set: test Average loss: 0.0699, test Accuracy: 9794/10000 (97.9400%)
#
# Epoch: 17,LR: 0.012288000000000002.
# Train set: train Average loss: 0.1037, train_Accuracy: 58151/60000 (96.9183%)
#
# Test set: test Average loss: 0.0779, test Accuracy: 9759/10000 (97.5900%)
#
# Epoch: 18,LR: 0.012288000000000002.
# Train set: train Average loss: 0.1061, train_Accuracy: 58067/60000 (96.7783%)
#
# Test set: test Average loss: 0.0841, test Accuracy: 9727/10000 (97.2700%)
#
# Epoch: 19,LR: 0.012288000000000002.
# Train set: train Average loss: 0.1043, train_Accuracy: 58164/60000 (96.9400%)
#
# Test set: test Average loss: 0.0802, test Accuracy: 9764/10000 (97.6400%)
#
# Epoch: 20,LR: 0.012288000000000002.
# Train set: train Average loss: 0.1058, train_Accuracy: 58079/60000 (96.7983%)
#
# Test set: test Average loss: 0.0885, test Accuracy: 9760/10000 (97.6000%)
#
# Epoch: 21,LR: 0.009830400000000003.
# Train set: train Average loss: 0.0990, train_Accuracy: 58202/60000 (97.0033%)
#
# Test set: test Average loss: 0.2032, test Accuracy: 9328/10000 (93.2800%)
#
# Epoch: 22,LR: 0.009830400000000003.
# Train set: train Average loss: 0.1019, train_Accuracy: 58178/60000 (96.9633%)
#
# Test set: test Average loss: 0.0980, test Accuracy: 9721/10000 (97.2100%)
#
# Epoch: 23,LR: 0.009830400000000003.
# Train set: train Average loss: 0.1010, train_Accuracy: 58139/60000 (96.8983%)
#
# Test set: test Average loss: 0.1330, test Accuracy: 9575/10000 (95.7500%)
#
# Epoch: 24,LR: 0.009830400000000003.
# Train set: train Average loss: 0.1014, train_Accuracy: 58194/60000 (96.9900%)
#
# Test set: test Average loss: 0.1262, test Accuracy: 9620/10000 (96.2000%)
#
# Epoch: 25,LR: 0.007864320000000003.
# Train set: train Average loss: 0.0913, train_Accuracy: 58377/60000 (97.2950%)
#
# Test set: test Average loss: 0.0719, test Accuracy: 9779/10000 (97.7900%)
#
# 2 l2 loss
# BN enabled for option: 2
# Model Summary:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 8, 28, 28]              80
#        BatchNorm2d-2            [-1, 8, 28, 28]              16
#             Conv2d-3           [-1, 16, 26, 26]           1,168
#        BatchNorm2d-4           [-1, 16, 26, 26]              32
#          MaxPool2d-5           [-1, 16, 13, 13]               0
#             Conv2d-6           [-1, 10, 13, 13]             170
#        BatchNorm2d-7           [-1, 10, 13, 13]              20
#             Conv2d-8           [-1, 14, 11, 11]           1,274
#        BatchNorm2d-9           [-1, 14, 11, 11]              28
#           Dropout-10           [-1, 14, 11, 11]               0
#            Conv2d-11             [-1, 16, 9, 9]           2,032
#       BatchNorm2d-12             [-1, 16, 9, 9]              32
#           Dropout-13             [-1, 16, 9, 9]               0
#            Conv2d-14             [-1, 20, 7, 7]           2,900
#       BatchNorm2d-15             [-1, 20, 7, 7]              40
#           Dropout-16             [-1, 20, 7, 7]               0
#         AvgPool2d-17             [-1, 20, 1, 1]               0
#            Conv2d-18             [-1, 10, 1, 1]             210
# ================================================================
# Total params: 8,002
# Trainable params: 8,002
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.40
# Params size (MB): 0.03
# Estimated Total Size (MB): 0.43
# ----------------------------------------------------------------
# Weight decay 0.0001 set for option: 2
# LOSS: l2 loss enabled
# Epoch: 1,LR: 0.03.
# Train set: train Average loss: 0.2510, train_Accuracy: 55598/60000 (92.6633%)
#
# Test set: test Average loss: 0.0594, test Accuracy: 9816/10000 (98.1600%)
#
# Epoch: 2,LR: 0.03.
# Train set: train Average loss: 0.0769, train_Accuracy: 58605/60000 (97.6750%)
#
# Test set: test Average loss: 0.0663, test Accuracy: 9796/10000 (97.9600%)
#
# Epoch: 3,LR: 0.03.
# Train set: train Average loss: 0.0615, train_Accuracy: 58869/60000 (98.1150%)
#
# Test set: test Average loss: 0.0367, test Accuracy: 9888/10000 (98.8800%)
#
# Epoch: 4,LR: 0.03.
# Train set: train Average loss: 0.0553, train_Accuracy: 58941/60000 (98.2350%)
#
# Test set: test Average loss: 0.0344, test Accuracy: 9887/10000 (98.8700%)
#
# Epoch: 5,LR: 0.024.
# Train set: train Average loss: 0.0465, train_Accuracy: 59147/60000 (98.5783%)
#
# Test set: test Average loss: 0.0241, test Accuracy: 9922/10000 (99.2200%)
#
# Epoch: 6,LR: 0.024.
# Train set: train Average loss: 0.0433, train_Accuracy: 59210/60000 (98.6833%)
#
# Test set: test Average loss: 0.0219, test Accuracy: 9933/10000 (99.3300%)
#
# Epoch: 7,LR: 0.024.
# Train set: train Average loss: 0.0442, train_Accuracy: 59198/60000 (98.6633%)
#
# Test set: test Average loss: 0.0294, test Accuracy: 9913/10000 (99.1300%)
#
# Epoch: 8,LR: 0.024.
# Train set: train Average loss: 0.0393, train_Accuracy: 59261/60000 (98.7683%)
#
# Test set: test Average loss: 0.0257, test Accuracy: 9900/10000 (99.0000%)
#
# Epoch: 9,LR: 0.019200000000000002.
# Train set: train Average loss: 0.0379, train_Accuracy: 59290/60000 (98.8167%)
#
# Test set: test Average loss: 0.0228, test Accuracy: 9931/10000 (99.3100%)
#
# Epoch: 10,LR: 0.019200000000000002.
# Train set: train Average loss: 0.0362, train_Accuracy: 59300/60000 (98.8333%)
#
# Test set: test Average loss: 0.0196, test Accuracy: 9932/10000 (99.3200%)
#
# Epoch: 11,LR: 0.019200000000000002.
# Train set: train Average loss: 0.0378, train_Accuracy: 59290/60000 (98.8167%)
#
# Test set: test Average loss: 0.0218, test Accuracy: 9931/10000 (99.3100%)
#
# Epoch: 12,LR: 0.019200000000000002.
# Train set: train Average loss: 0.0368, train_Accuracy: 59283/60000 (98.8050%)
#
# Test set: test Average loss: 0.0196, test Accuracy: 9933/10000 (99.3300%)
#
# Epoch: 13,LR: 0.015360000000000002.
# Train set: train Average loss: 0.0331, train_Accuracy: 59370/60000 (98.9500%)
#
# Test set: test Average loss: 0.0190, test Accuracy: 9944/10000 (99.4400%)
#
# Epoch: 14,LR: 0.015360000000000002.
# Train set: train Average loss: 0.0329, train_Accuracy: 59396/60000 (98.9933%)
#
# Test set: test Average loss: 0.0186, test Accuracy: 9944/10000 (99.4400%)
#
# Epoch: 15,LR: 0.015360000000000002.
# Train set: train Average loss: 0.0324, train_Accuracy: 59411/60000 (99.0183%)
#
# Test set: test Average loss: 0.0193, test Accuracy: 9943/10000 (99.4300%)
#
# Epoch: 16,LR: 0.015360000000000002.
# Train set: train Average loss: 0.0324, train_Accuracy: 59393/60000 (98.9883%)
#
# Test set: test Average loss: 0.0212, test Accuracy: 9931/10000 (99.3100%)
#
# Epoch: 17,LR: 0.012288000000000002.
# Train set: train Average loss: 0.0292, train_Accuracy: 59450/60000 (99.0833%)
#
# Test set: test Average loss: 0.0173, test Accuracy: 9942/10000 (99.4200%)
#
# Epoch: 18,LR: 0.012288000000000002.
# Train set: train Average loss: 0.0291, train_Accuracy: 59466/60000 (99.1100%)
#
# Test set: test Average loss: 0.0177, test Accuracy: 9940/10000 (99.4000%)
#
# Epoch: 19,LR: 0.012288000000000002.
# Train set: train Average loss: 0.0304, train_Accuracy: 59389/60000 (98.9817%)
#
# Test set: test Average loss: 0.0205, test Accuracy: 9939/10000 (99.3900%)
#
# Epoch: 20,LR: 0.012288000000000002.
# Train set: train Average loss: 0.0288, train_Accuracy: 59458/60000 (99.0967%)
#
# Test set: test Average loss: 0.0178, test Accuracy: 9938/10000 (99.3800%)
#
# Epoch: 21,LR: 0.009830400000000003.
# Train set: train Average loss: 0.0274, train_Accuracy: 59477/60000 (99.1283%)
#
# Test set: test Average loss: 0.0173, test Accuracy: 9946/10000 (99.4600%)
#
# Epoch: 22,LR: 0.009830400000000003.
# Train set: train Average loss: 0.0275, train_Accuracy: 59498/60000 (99.1633%)
#
# Test set: test Average loss: 0.0163, test Accuracy: 9944/10000 (99.4400%)
#
# Epoch: 23,LR: 0.009830400000000003.
# Train set: train Average loss: 0.0255, train_Accuracy: 59544/60000 (99.2400%)
#
# Test set: test Average loss: 0.0159, test Accuracy: 9944/10000 (99.4400%)
#
# Epoch: 24,LR: 0.009830400000000003.
# Train set: train Average loss: 0.0269, train_Accuracy: 59495/60000 (99.1583%)
#
# Test set: test Average loss: 0.0159, test Accuracy: 9952/10000 (99.5200%)
#
# Epoch: 25,LR: 0.007864320000000003.
# Train set: train Average loss: 0.0261, train_Accuracy: 59512/60000 (99.1867%)
#
# Test set: test Average loss: 0.0174, test Accuracy: 9945/10000 (99.4500%)
#
# 3 l1&l2 loss
# BN enabled for option: 3
# Model Summary:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 8, 28, 28]              80
#        BatchNorm2d-2            [-1, 8, 28, 28]              16
#             Conv2d-3           [-1, 16, 26, 26]           1,168
#        BatchNorm2d-4           [-1, 16, 26, 26]              32
#          MaxPool2d-5           [-1, 16, 13, 13]               0
#             Conv2d-6           [-1, 10, 13, 13]             170
#        BatchNorm2d-7           [-1, 10, 13, 13]              20
#             Conv2d-8           [-1, 14, 11, 11]           1,274
#        BatchNorm2d-9           [-1, 14, 11, 11]              28
#           Dropout-10           [-1, 14, 11, 11]               0
#            Conv2d-11             [-1, 16, 9, 9]           2,032
#       BatchNorm2d-12             [-1, 16, 9, 9]              32
#           Dropout-13             [-1, 16, 9, 9]               0
#            Conv2d-14             [-1, 20, 7, 7]           2,900
#       BatchNorm2d-15             [-1, 20, 7, 7]              40
#           Dropout-16             [-1, 20, 7, 7]               0
#         AvgPool2d-17             [-1, 20, 1, 1]               0
#            Conv2d-18             [-1, 10, 1, 1]             210
# ================================================================
# Total params: 8,002
# Trainable params: 8,002
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.40
# Params size (MB): 0.03
# Estimated Total Size (MB): 0.43
# ----------------------------------------------------------------
# Weight decay 0.0001 set for option: 3
# LOSS: l1l2 loss enabled
# Epoch: 1,LR: 0.03.
# Train set: train Average loss: 0.2871, train_Accuracy: 55108/60000 (91.8467%)
#
# Test set: test Average loss: 0.1447, test Accuracy: 9608/10000 (96.0800%)
#
# Epoch: 2,LR: 0.03.
# Train set: train Average loss: 0.1412, train_Accuracy: 57458/60000 (95.7633%)
#
# Test set: test Average loss: 0.1524, test Accuracy: 9568/10000 (95.6800%)
#
# Epoch: 3,LR: 0.03.
# Train set: train Average loss: 0.1369, train_Accuracy: 57565/60000 (95.9417%)
#
# Test set: test Average loss: 0.1773, test Accuracy: 9456/10000 (94.5600%)
#
# Epoch: 4,LR: 0.03.
# Train set: train Average loss: 0.1317, train_Accuracy: 57670/60000 (96.1167%)
#
# Test set: test Average loss: 0.2159, test Accuracy: 9338/10000 (93.3800%)
#
# Epoch: 5,LR: 0.024.
# Train set: train Average loss: 0.1234, train_Accuracy: 57829/60000 (96.3817%)
#
# Test set: test Average loss: 0.0972, test Accuracy: 9698/10000 (96.9800%)
#
# Epoch: 6,LR: 0.024.
# Train set: train Average loss: 0.1245, train_Accuracy: 57712/60000 (96.1867%)
#
# Test set: test Average loss: 0.0821, test Accuracy: 9751/10000 (97.5100%)
#
# Epoch: 7,LR: 0.024.
# Train set: train Average loss: 0.1205, train_Accuracy: 57879/60000 (96.4650%)
#
# Test set: test Average loss: 0.1013, test Accuracy: 9678/10000 (96.7800%)
#
# Epoch: 8,LR: 0.024.
# Train set: train Average loss: 0.1209, train_Accuracy: 57828/60000 (96.3800%)
#
# Test set: test Average loss: 0.0797, test Accuracy: 9781/10000 (97.8100%)
#
# Epoch: 9,LR: 0.019200000000000002.
# Train set: train Average loss: 0.1113, train_Accuracy: 57981/60000 (96.6350%)
#
# Test set: test Average loss: 0.0996, test Accuracy: 9683/10000 (96.8300%)
#
# Epoch: 10,LR: 0.019200000000000002.
# Train set: train Average loss: 0.1148, train_Accuracy: 57909/60000 (96.5150%)
#
# Test set: test Average loss: 0.1439, test Accuracy: 9508/10000 (95.0800%)
#
# Epoch: 11,LR: 0.019200000000000002.
# Train set: train Average loss: 0.1137, train_Accuracy: 57939/60000 (96.5650%)
#
# Test set: test Average loss: 0.0682, test Accuracy: 9797/10000 (97.9700%)
#
# Epoch: 12,LR: 0.019200000000000002.
# Train set: train Average loss: 0.1150, train_Accuracy: 57931/60000 (96.5517%)
#
# Test set: test Average loss: 0.1129, test Accuracy: 9666/10000 (96.6600%)
#
# Epoch: 13,LR: 0.015360000000000002.
# Train set: train Average loss: 0.1069, train_Accuracy: 58069/60000 (96.7817%)
#
# Test set: test Average loss: 0.0890, test Accuracy: 9732/10000 (97.3200%)
#
# Epoch: 14,LR: 0.015360000000000002.
# Train set: train Average loss: 0.1103, train_Accuracy: 58011/60000 (96.6850%)
#
# Test set: test Average loss: 0.0635, test Accuracy: 9813/10000 (98.1300%)
#
# Epoch: 15,LR: 0.015360000000000002.
# Train set: train Average loss: 0.1088, train_Accuracy: 58055/60000 (96.7583%)
#
# Test set: test Average loss: 0.0822, test Accuracy: 9739/10000 (97.3900%)
#
# Epoch: 16,LR: 0.015360000000000002.
# Train set: train Average loss: 0.1095, train_Accuracy: 58004/60000 (96.6733%)
#
# Test set: test Average loss: 0.1127, test Accuracy: 9642/10000 (96.4200%)
#
# Epoch: 17,LR: 0.012288000000000002.
# Train set: train Average loss: 0.0993, train_Accuracy: 58241/60000 (97.0683%)
#
# Test set: test Average loss: 0.0759, test Accuracy: 9757/10000 (97.5700%)
#
# Epoch: 18,LR: 0.012288000000000002.
# Train set: train Average loss: 0.1037, train_Accuracy: 58168/60000 (96.9467%)
#
# Test set: test Average loss: 0.0951, test Accuracy: 9724/10000 (97.2400%)
#
# Epoch: 19,LR: 0.012288000000000002.
# Train set: train Average loss: 0.1025, train_Accuracy: 58185/60000 (96.9750%)
#
# Test set: test Average loss: 0.0992, test Accuracy: 9687/10000 (96.8700%)
#
# Epoch: 20,LR: 0.012288000000000002.
# Train set: train Average loss: 0.1043, train_Accuracy: 58096/60000 (96.8267%)
#
# Test set: test Average loss: 0.0837, test Accuracy: 9737/10000 (97.3700%)
#
# Epoch: 21,LR: 0.009830400000000003.
# Train set: train Average loss: 0.0946, train_Accuracy: 58290/60000 (97.1500%)
#
# Test set: test Average loss: 0.1281, test Accuracy: 9645/10000 (96.4500%)
#
# Epoch: 22,LR: 0.009830400000000003.
# Train set: train Average loss: 0.0976, train_Accuracy: 58237/60000 (97.0617%)
#
# Test set: test Average loss: 0.0771, test Accuracy: 9759/10000 (97.5900%)
#
# Epoch: 23,LR: 0.009830400000000003.
# Train set: train Average loss: 0.0972, train_Accuracy: 58273/60000 (97.1217%)
#
# Test set: test Average loss: 0.0954, test Accuracy: 9710/10000 (97.1000%)
#
# Epoch: 24,LR: 0.009830400000000003.
# Train set: train Average loss: 0.0999, train_Accuracy: 58224/60000 (97.0400%)
#
# Test set: test Average loss: 0.0662, test Accuracy: 9779/10000 (97.7900%)
#
# Epoch: 25,LR: 0.007864320000000003.
# Train set: train Average loss: 0.0906, train_Accuracy: 58366/60000 (97.2767%)
#
# Test set: test Average loss: 0.0921, test Accuracy: 9730/10000 (97.3000%)
#
# 4 gbn loss
# GBN Enabled & BN disabled for option: 4
# Model Summary:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 8, 28, 28]              80
#     GhostBatchNorm-2            [-1, 8, 28, 28]              16
#             Conv2d-3           [-1, 16, 26, 26]           1,168
#     GhostBatchNorm-4           [-1, 16, 26, 26]              32
#          MaxPool2d-5           [-1, 16, 13, 13]               0
#             Conv2d-6           [-1, 10, 13, 13]             170
#     GhostBatchNorm-7           [-1, 10, 13, 13]              20
#             Conv2d-8           [-1, 14, 11, 11]           1,274
#     GhostBatchNorm-9           [-1, 14, 11, 11]              28
#           Dropout-10           [-1, 14, 11, 11]               0
#            Conv2d-11             [-1, 16, 9, 9]           2,032
#    GhostBatchNorm-12             [-1, 16, 9, 9]              32
#           Dropout-13             [-1, 16, 9, 9]               0
#            Conv2d-14             [-1, 20, 7, 7]           2,900
#    GhostBatchNorm-15             [-1, 20, 7, 7]              40
#           Dropout-16             [-1, 20, 7, 7]               0
#         AvgPool2d-17             [-1, 20, 1, 1]               0
#            Conv2d-18             [-1, 10, 1, 1]             210
# ================================================================
# Total params: 8,002
# Trainable params: 8,002
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.40
# Params size (MB): 0.03
# Estimated Total Size (MB): 0.43
# ----------------------------------------------------------------
# LOSS: gbn loss enabled
# Epoch: 1,LR: 0.03.
# Train set: train Average loss: 0.2464, train_Accuracy: 55702/60000 (92.8367%)
#
# Test set: test Average loss: 0.0517, test Accuracy: 9835/10000 (98.3500%)
#
# Epoch: 2,LR: 0.03.
# Train set: train Average loss: 0.0818, train_Accuracy: 58505/60000 (97.5083%)
#
# Test set: test Average loss: 0.0420, test Accuracy: 9881/10000 (98.8100%)
#
# Epoch: 3,LR: 0.03.
# Train set: train Average loss: 0.0638, train_Accuracy: 58852/60000 (98.0867%)
#
# Test set: test Average loss: 0.0345, test Accuracy: 9898/10000 (98.9800%)
#
# Epoch: 4,LR: 0.03.
# Train set: train Average loss: 0.0571, train_Accuracy: 58925/60000 (98.2083%)
#
# Test set: test Average loss: 0.0364, test Accuracy: 9878/10000 (98.7800%)
#
# Epoch: 5,LR: 0.024.
# Train set: train Average loss: 0.0498, train_Accuracy: 59053/60000 (98.4217%)
#
# Test set: test Average loss: 0.0256, test Accuracy: 9918/10000 (99.1800%)
#
# Epoch: 6,LR: 0.024.
# Train set: train Average loss: 0.0466, train_Accuracy: 59113/60000 (98.5217%)
#
# Test set: test Average loss: 0.0243, test Accuracy: 9922/10000 (99.2200%)
#
# Epoch: 7,LR: 0.024.
# Train set: train Average loss: 0.0427, train_Accuracy: 59220/60000 (98.7000%)
#
# Test set: test Average loss: 0.0214, test Accuracy: 9930/10000 (99.3000%)
#
# Epoch: 8,LR: 0.024.
# Train set: train Average loss: 0.0433, train_Accuracy: 59182/60000 (98.6367%)
#
# Test set: test Average loss: 0.0261, test Accuracy: 9912/10000 (99.1200%)
#
# Epoch: 9,LR: 0.019200000000000002.
# Train set: train Average loss: 0.0394, train_Accuracy: 59238/60000 (98.7300%)
#
# Test set: test Average loss: 0.0241, test Accuracy: 9922/10000 (99.2200%)
#
# Epoch: 10,LR: 0.019200000000000002.
# Train set: train Average loss: 0.0374, train_Accuracy: 59290/60000 (98.8167%)
#
# Test set: test Average loss: 0.0216, test Accuracy: 9935/10000 (99.3500%)
#
# Epoch: 11,LR: 0.019200000000000002.
# Train set: train Average loss: 0.0381, train_Accuracy: 59280/60000 (98.8000%)
#
# Test set: test Average loss: 0.0206, test Accuracy: 9939/10000 (99.3900%)
#
# Epoch: 12,LR: 0.019200000000000002.
# Train set: train Average loss: 0.0359, train_Accuracy: 59340/60000 (98.9000%)
#
# Test set: test Average loss: 0.0196, test Accuracy: 9938/10000 (99.3800%)
#
# Epoch: 13,LR: 0.015360000000000002.
# Train set: train Average loss: 0.0340, train_Accuracy: 59382/60000 (98.9700%)
#
# Test set: test Average loss: 0.0201, test Accuracy: 9938/10000 (99.3800%)
#
# Epoch: 14,LR: 0.015360000000000002.
# Train set: train Average loss: 0.0345, train_Accuracy: 59344/60000 (98.9067%)
#
# Test set: test Average loss: 0.0182, test Accuracy: 9945/10000 (99.4500%)
#
# Epoch: 15,LR: 0.015360000000000002.
# Train set: train Average loss: 0.0328, train_Accuracy: 59357/60000 (98.9283%)
#
# Test set: test Average loss: 0.0198, test Accuracy: 9943/10000 (99.4300%)
#
# Epoch: 16,LR: 0.015360000000000002.
# Train set: train Average loss: 0.0335, train_Accuracy: 59355/60000 (98.9250%)
#
# Test set: test Average loss: 0.0217, test Accuracy: 9934/10000 (99.3400%)
#
# Epoch: 17,LR: 0.012288000000000002.
# Train set: train Average loss: 0.0315, train_Accuracy: 59399/60000 (98.9983%)
#
# Test set: test Average loss: 0.0192, test Accuracy: 9940/10000 (99.4000%)
#
# Epoch: 18,LR: 0.012288000000000002.
# Train set: train Average loss: 0.0313, train_Accuracy: 59374/60000 (98.9567%)
#
# Test set: test Average loss: 0.0184, test Accuracy: 9937/10000 (99.3700%)
#
# Epoch: 19,LR: 0.012288000000000002.
# Train set: train Average loss: 0.0291, train_Accuracy: 59439/60000 (99.0650%)
#
# Test set: test Average loss: 0.0181, test Accuracy: 9946/10000 (99.4600%)
#
# Epoch: 20,LR: 0.012288000000000002.
# Train set: train Average loss: 0.0320, train_Accuracy: 59371/60000 (98.9517%)
#
# Test set: test Average loss: 0.0195, test Accuracy: 9932/10000 (99.3200%)
#
# Epoch: 21,LR: 0.009830400000000003.
# Train set: train Average loss: 0.0283, train_Accuracy: 59484/60000 (99.1400%)
#
# Test set: test Average loss: 0.0173, test Accuracy: 9945/10000 (99.4500%)
#
# Epoch: 22,LR: 0.009830400000000003.
# Train set: train Average loss: 0.0276, train_Accuracy: 59490/60000 (99.1500%)
#
# Test set: test Average loss: 0.0185, test Accuracy: 9945/10000 (99.4500%)
#
# Epoch: 23,LR: 0.009830400000000003.
# Train set: train Average loss: 0.0284, train_Accuracy: 59455/60000 (99.0917%)
#
# Test set: test Average loss: 0.0200, test Accuracy: 9937/10000 (99.3700%)
#
# Epoch: 24,LR: 0.009830400000000003.
# Train set: train Average loss: 0.0275, train_Accuracy: 59489/60000 (99.1483%)
#
# Test set: test Average loss: 0.0176, test Accuracy: 9946/10000 (99.4600%)
#
# Epoch: 25,LR: 0.007864320000000003.
# Train set: train Average loss: 0.0278, train_Accuracy: 59458/60000 (99.0967%)
#
# Test set: test Average loss: 0.0181, test Accuracy: 9949/10000 (99.4900%)
#
# 5 l1l2gbn loss
# GBN Enabled & BN disabled for option: 5
# Model Summary:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 8, 28, 28]              80
#     GhostBatchNorm-2            [-1, 8, 28, 28]              16
#             Conv2d-3           [-1, 16, 26, 26]           1,168
#     GhostBatchNorm-4           [-1, 16, 26, 26]              32
#          MaxPool2d-5           [-1, 16, 13, 13]               0
#             Conv2d-6           [-1, 10, 13, 13]             170
#     GhostBatchNorm-7           [-1, 10, 13, 13]              20
#             Conv2d-8           [-1, 14, 11, 11]           1,274
#     GhostBatchNorm-9           [-1, 14, 11, 11]              28
#           Dropout-10           [-1, 14, 11, 11]               0
#            Conv2d-11             [-1, 16, 9, 9]           2,032
#    GhostBatchNorm-12             [-1, 16, 9, 9]              32
#           Dropout-13             [-1, 16, 9, 9]               0
#            Conv2d-14             [-1, 20, 7, 7]           2,900
#    GhostBatchNorm-15             [-1, 20, 7, 7]              40
#           Dropout-16             [-1, 20, 7, 7]               0
#         AvgPool2d-17             [-1, 20, 1, 1]               0
#            Conv2d-18             [-1, 10, 1, 1]             210
# ================================================================
# Total params: 8,002
# Trainable params: 8,002
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.40
# Params size (MB): 0.03
# Estimated Total Size (MB): 0.43
# ----------------------------------------------------------------
# Weight decay 0.0001 set for option: 5
# LOSS: l1l2gbn loss enabled
# Epoch: 1,LR: 0.03.
# Train set: train Average loss: 0.2733, train_Accuracy: 55178/60000 (91.9633%)
#
# Test set: test Average loss: 0.0530, test Accuracy: 9848/10000 (98.4800%)
#
# Epoch: 2,LR: 0.03.
# Train set: train Average loss: 0.0872, train_Accuracy: 58438/60000 (97.3967%)
#
# Test set: test Average loss: 0.0378, test Accuracy: 9895/10000 (98.9500%)
#
# Epoch: 3,LR: 0.03.
# Train set: train Average loss: 0.0691, train_Accuracy: 58733/60000 (97.8883%)
#
# Test set: test Average loss: 0.0353, test Accuracy: 9889/10000 (98.8900%)
#
# Epoch: 4,LR: 0.03.
# Train set: train Average loss: 0.0637, train_Accuracy: 58841/60000 (98.0683%)
#
# Test set: test Average loss: 0.0327, test Accuracy: 9910/10000 (99.1000%)
#
# Epoch: 5,LR: 0.024.
# Train set: train Average loss: 0.0546, train_Accuracy: 59004/60000 (98.3400%)
#
# Test set: test Average loss: 0.0265, test Accuracy: 9918/10000 (99.1800%)
#
# Epoch: 6,LR: 0.024.
# Train set: train Average loss: 0.0512, train_Accuracy: 59054/60000 (98.4233%)
#
# Test set: test Average loss: 0.0249, test Accuracy: 9918/10000 (99.1800%)
#
# Epoch: 7,LR: 0.024.
# Train set: train Average loss: 0.0489, train_Accuracy: 59078/60000 (98.4633%)
#
# Test set: test Average loss: 0.0263, test Accuracy: 9918/10000 (99.1800%)
#
# Epoch: 8,LR: 0.024.
# Train set: train Average loss: 0.0472, train_Accuracy: 59142/60000 (98.5700%)
#
# Test set: test Average loss: 0.0242, test Accuracy: 9927/10000 (99.2700%)
#
# Epoch: 9,LR: 0.019200000000000002.
# Train set: train Average loss: 0.0442, train_Accuracy: 59161/60000 (98.6017%)
#
# Test set: test Average loss: 0.0257, test Accuracy: 9918/10000 (99.1800%)
#
# Epoch: 10,LR: 0.019200000000000002.
# Train set: train Average loss: 0.0408, train_Accuracy: 59273/60000 (98.7883%)
#
# Test set: test Average loss: 0.0192, test Accuracy: 9939/10000 (99.3900%)
#
# Epoch: 11,LR: 0.019200000000000002.
# Train set: train Average loss: 0.0414, train_Accuracy: 59226/60000 (98.7100%)
#
# Test set: test Average loss: 0.0227, test Accuracy: 9935/10000 (99.3500%)
#
# Epoch: 12,LR: 0.019200000000000002.
# Train set: train Average loss: 0.0395, train_Accuracy: 59235/60000 (98.7250%)
#
# Test set: test Average loss: 0.0223, test Accuracy: 9926/10000 (99.2600%)
#
# Epoch: 13,LR: 0.015360000000000002.
# Train set: train Average loss: 0.0373, train_Accuracy: 59316/60000 (98.8600%)
#
# Test set: test Average loss: 0.0223, test Accuracy: 9932/10000 (99.3200%)
#
# Epoch: 14,LR: 0.015360000000000002.
# Train set: train Average loss: 0.0380, train_Accuracy: 59295/60000 (98.8250%)
#
# Test set: test Average loss: 0.0216, test Accuracy: 9941/10000 (99.4100%)
#
# Epoch: 15,LR: 0.015360000000000002.
# Train set: train Average loss: 0.0360, train_Accuracy: 59350/60000 (98.9167%)
#
# Test set: test Average loss: 0.0219, test Accuracy: 9927/10000 (99.2700%)
#
# Epoch: 16,LR: 0.015360000000000002.
# Train set: train Average loss: 0.0342, train_Accuracy: 59367/60000 (98.9450%)
#
# Test set: test Average loss: 0.0209, test Accuracy: 9932/10000 (99.3200%)
#
# Epoch: 17,LR: 0.012288000000000002.
# Train set: train Average loss: 0.0346, train_Accuracy: 59384/60000 (98.9733%)
#
# Test set: test Average loss: 0.0197, test Accuracy: 9935/10000 (99.3500%)
#
# Epoch: 18,LR: 0.012288000000000002.
# Train set: train Average loss: 0.0341, train_Accuracy: 59357/60000 (98.9283%)
#
# Test set: test Average loss: 0.0201, test Accuracy: 9936/10000 (99.3600%)
#
# Epoch: 19,LR: 0.012288000000000002.
# Train set: train Average loss: 0.0319, train_Accuracy: 59416/60000 (99.0267%)
#
# Test set: test Average loss: 0.0187, test Accuracy: 9941/10000 (99.4100%)
#
# Epoch: 20,LR: 0.012288000000000002.
# Train set: train Average loss: 0.0340, train_Accuracy: 59378/60000 (98.9633%)
#
# Test set: test Average loss: 0.0185, test Accuracy: 9944/10000 (99.4400%)
#
# Epoch: 21,LR: 0.009830400000000003.
# Train set: train Average loss: 0.0323, train_Accuracy: 59394/60000 (98.9900%)
#
# Test set: test Average loss: 0.0186, test Accuracy: 9936/10000 (99.3600%)
#
# Epoch: 22,LR: 0.009830400000000003.
# Train set: train Average loss: 0.0310, train_Accuracy: 59444/60000 (99.0733%)
#
# Test set: test Average loss: 0.0185, test Accuracy: 9944/10000 (99.4400%)
#
# Epoch: 23,LR: 0.009830400000000003.
# Train set: train Average loss: 0.0308, train_Accuracy: 59431/60000 (99.0517%)
#
# Test set: test Average loss: 0.0181, test Accuracy: 9940/10000 (99.4000%)
#
# Epoch: 24,LR: 0.009830400000000003.
# Train set: train Average loss: 0.0313, train_Accuracy: 59403/60000 (99.0050%)
#
# Test set: test Average loss: 0.0189, test Accuracy: 9940/10000 (99.4000%)
#
# Epoch: 25,LR: 0.007864320000000003.
# Train set: train Average loss: 0.0295, train_Accuracy: 59452/60000 (99.0867%)
#
# Test set: test Average loss: 0.0184, test Accuracy: 9941/10000 (99.4100%)

# %%
print(type(val_losses))
print(val_losses[0])
# Out:
# <class 'list'>
# [0.200752188038826, 0.101362257245183, 0.18481947920322417, 0.09897676264047622, 0.12873549226522446, 0.20674600977897645, 0.31424349138736724, 0.0691275066792965, 0.09559733887314796, 0.08825906487703324, 0.09111487046182155, 0.14347786620259284, 0.1503140803694725, 0.06539265607595443, 0.09495950067937374, 0.06989950978755952, 0.07791333914399147, 0.08408322439193726, 0.08018805867433548, 0.08850222775042058, 0.20319608428478242, 0.09797307643294334, 0.13299060874581337, 0.1262349791586399, 0.07193975643292069]

# %%
import matplotlib.pyplot as plt

epoch = 25
plt.figure(figsize=(12,12))
plt.subplot(2,1,1)
ax = plt.gca()
ax.set_xlim([0, epoch+2])
plt.ylabel('Loss')
plt.title('Validation Loss Plot')
plt.plot(range(1, epoch+1), val_losses[0], 'r', label='l1 val Loss')
plt.plot(range(1, epoch+1), val_losses[1], 'b', label='l2 Val Loss')
plt.plot(range(1, epoch+1), val_losses[2], 'c', label='l1l2 Val Loss')
plt.plot(range(1, epoch+1), val_losses[3], 'g', label='gbn Val Loss')
plt.plot(range(1, epoch+1), val_losses[4], 'y', label='l1l2gbn Val Loss')

# c ,g ,y

ax.grid(linestyle='-.')
plt.legend()
plt.subplot(2,1,2)

ax = plt.gca()
ax.set_xlim([0, epoch+2])
plt.ylabel('Accuracy')
plt.title('Validation Accuracy plot')
plt.plot(range(1, epoch+1), val_accs[0], 'r', label='l1 Accuracy')
plt.plot(range(1, epoch+1), val_accs[1], 'b', label='l2 Accuracy')
plt.plot(range(1, epoch+1), val_accs[2], 'c', label='l1l2 Accuracy')
plt.plot(range(1, epoch+1), val_accs[3], 'g', label='gbn Accuracy')
plt.plot(range(1, epoch+1), val_accs[4], 'y', label='l1l2gbn Accuracy')

ax.grid(linestyle='-.')
plt.legend()
plt.show()
